# %%
# %run MovieSimilarity.py

# %%
get_TransformedData(lens)
# Out:
#          release_date avg_rating gender_preference age
# Movie Id
# 1           1988-1998         R4                 M  A3
# 2           1988-1998         R3                 M  A3
# 3           1988-1998         R3                 M  A3
# 4           1988-1998         R4                 M  A3
# 5           1988-1998         R3                 M  A3
# 6           1988-1998         R4                 M  A3
# 7           1988-1998         R4                 M  A3
# 8           1988-1998         R4                 M  A3
# 9           1988-1998         R4                 M  A3
# 10          1988-1998         R4                 M  A4
# 11          1988-1998         R4                 M  A3
# 12          1988-1998         R5                 M  A3
# 13          1988-1998         R4                 M  A3
# 14          1988-1998         R4                 M  A4
# 15          1988-1998         R4                 M  A3
# 16          1988-1998         R3                 M  A3
# ...

# %%
x = getSimilarityTable(lens)

# %%
vals = [ v for v in x.ix[1].index.drop(1) if x.ix[1][v] == 4]

# %%
lens[lens['user_id']==1]
# Out:
#        movie_id                                              title  \
# 20103         1                                   Toy Story (1995)
# 20104         2                                   GoldenEye (1995)
# 20105         3                                  Four Rooms (1995)
# 20106         4                                  Get Shorty (1995)
# 20107         5                                     Copycat (1995)
# 20108         6  Shanghai Triad (Yao a yao yao dao waipo qiao) ...
# 20109         7                              Twelve Monkeys (1995)
# 20110         8                                        Babe (1995)
# 20111         9                            Dead Man Walking (1995)
# 20112        10                                 Richard III (1995)
# 20113        11                               Seven (Se7en) (1995)
# 20114        12                         Usual Suspects, The (1995)
# 20115        13                            Mighty Aphrodite (1995)
# ...
